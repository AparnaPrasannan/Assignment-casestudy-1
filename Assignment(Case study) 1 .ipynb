# %%
## 1. Read the dataset to python environment

# %%
import pandas as pd

# %%
import numpy as np

# %%
ds=pd.read_excel("C:\\Users\\hp\\Downloads\\iris.xls")

# %%
## 2. Display the columns in the dataset

# %%
print(ds)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
## 3.Calculate the mean of each column of the dataset

# %%
## Mean of column 'SL'

# %%
ds["SL"].mean()
# Out:
# 5.843333333333335

# %%
## Mean of column 'SW'

# %%
ds["SW"].mean()
# Out:
# 3.0540000000000007

# %%
## mean of column 'PL'

# %%
ds["PL"].mean()
# Out:
# 3.7586666666666693

# %%
## mean of column 'PW'

# %%
ds["PW"].mean()
# Out:
# 1.1986666666666672

# %%
## 4. Check for the null values present in the dataset

# %%
ds.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
## 5.Visualizations

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
## 1. Histogram

# %%
plt.figure(figsize=(10,7))
plt.hist(ds['SL'])
plt.title("SL map",c='green',fontsize='20')
plt.xlabel('Value')
plt.ylabel('Numbers')
plt.show()

# %%
## 2.Countplot

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=ds['SL'])
plt.title('Countplot on SL')
plt.show()

# %%
## 3. Violin plot

# %%
plt.figure(figsize=(26,8))
sns.violinplot(x=ds['SL'],y=ds['SW'],z=ds['PL'],hue=ds['Classification'])
plt.title('Violin plot',fontsize='25')
plt.xlabel('SL',fontsize='15')
plt.ylabel('SW',fontsize='15')
plt.show()
